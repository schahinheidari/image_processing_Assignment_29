# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
logo = np.ones((600, 1200, 3), dtype="uint8")* 60
plt.imshow(logo)

# %%
#red
logo[200:300, 200:300] = (246,83,20)
#bleu
logo[310:410, 200:300] = (0,161,241)
#green
logo[200:300, 310:410] = (124, 187, 0)
#yellow
logo[310:410, 310:410] = (255, 187, 0)

# %%
# text
cv.putText(logo,"Microsoft", (440, 320), cv.FONT_HERSHEY_COMPLEX_SMALL, 5,(255,255,255),8)
#logo = cv.cvtColor(logo, cv.COLOR_RGB2BGR)
#cv.imwrite("output/logo.jpg", logo)
plt.imshow(logo)
